# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('aids.csv')

# %%
df
# Out:
#                                  Country  Year  \
# 0                            Afghanistan  1990
# 1                                Algeria  1990
# 2                                 Angola  1990
# 3                              Argentina  1990
# 4                              Australia  1990
# ...                                  ...   ...
# 2569  Venezuela (Bolivarian Republic of)  2015
# 2570                            Viet Nam  2015
# 2571                               Yemen  2015
# 2572                              Zambia  2015
# 2573                            Zimbabwe  2015
#
#       Data.AIDS-Related Deaths.AIDS Orphans  Data.AIDS-Related Deaths.Adults  \
# 0                                        44                                8
# 1                                       219                               24
# 2                                      5914                              849
# 3                                       632                              391
# ...

# %%
x =df.loc[:,["Year","Data.AIDS-Related Deaths.All Ages"]]

# %%
x.plot(xlabel='year',ylabel='death')
# Out:
# <AxesSubplot:xlabel='year', ylabel='death'>
