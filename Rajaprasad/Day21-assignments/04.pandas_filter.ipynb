# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('covid.csv')

# %%
x = df.loc[:,['Data.Cases','Data.Deaths']]

# %%
x.plot(xlabel="Data.cases" ,ylabel="Data.deaths")
# Out:
# <AxesSubplot:xlabel='Data.cases', ylabel='Data.deaths'>
